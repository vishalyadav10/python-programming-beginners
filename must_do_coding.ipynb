# %%
#splitting_integer
b=[int(i) for i in str(12345)]
print(b)

# %%
#print_the_pattern
n=int(input())
def printPat(n):
    count = n
    output = ""
    for i in range(n):
        for j in range(n,0,-1):
            output += (str(j)+' ') * count
        output += '$ '
        count -= 1
    return output
printPat(n)

# %%
#ap
t=int(input())
for _ in range(t):
    np=input().split()
    n=int(np[0])
    p=int(np[1])
    k=int(input())
    d=p-n
    res=n+(k-1)*d
    print(res)

# %%
#gp
import math
t=int(input())
for _ in range(t):
    np=input().split()
    n=int(np[0])
    p=int(np[1])
    k=int(input())
    print(int(math.floor(n*pow((p/n),k-1))))

# %%
#closest_number
t=int(input())
for i in range(t):
    s= input()
    s= s.split(" ")
    n=int(s[0])
    m=int(s[1])
    m=abs(m)
    
    q=n // m
    n1= m* (q+1) #one_multiple_ahead
    n2= m* (q) #one_multiple_behind
    diff1 = n1 -(n)
    diff2 = (n) - n2
    if diff1 > diff2:
        print(n2)
    elif diff2 > diff1:
        print(n1)
    else:
        if(q>0):
            print(n1)
        else:
            print(n2)

# %%
#armstrong_number
t=int(input())
for i in range(t):
    s=input()
    a=[]
    for i in range(len(s)):
        a.append(int(s[i])**3)
    s=int(s)
    if sum(a)==s:
        print("YES")
    else:
        print("NO")

# %%
#palindrome
t=int(input())
for _ in range(t):
    n=input()
    a=[]
    for i in range(len(n)):
        a.append(int(n[i]))
    s=sum(a)
    b=str(s)
    if b==b[::-1]:
        print("YES")
    else:
        print("NO")

# %%
#decimal to binary and vice versa
n=int(input())
s=bin(n).replace("0b"," ")
print(s)
#vice
s=input()
a=int(s,2)
print(a)

# %%
#jumping_numbers
# Class queue for use later 
class Queue: 
	def __init__(self): 
		self.lst = [] 

	def is_empty(self): 
		return self.lst == [] 

	def enqueue(self, elem): 
		self.lst.append(elem) 

	def dequeue(self): 
		return self.lst.pop(0) 

# Prints all jumping numbers smaller than or equal to 
# x starting with 'num'. It mainly does BFS starting 
# from 'num'. 
def bfs(x, num): 

	# Create a queue and enqueue i to it 
	q = Queue() 
	q.enqueue(num) 

	# Do BFS starting from 1 
	while (not q.is_empty()): 
		num = q.dequeue() 

		if num<= x: 
			print(str(num), end =' ') 
			last_dig = num % 10

			# If last digit is 0, append next digit only 
			if last_dig == 0: 
				q.enqueue((num * 10) + (last_dig + 1)) 

			# If last digit is 9, append previous digit 
			# only 
			elif last_dig == 9: 
				q.enqueue((num * 10) + (last_dig - 1)) 

			# If last digit is neighter 0 nor 9, append 
			# both previous digit and next digit 
			else: 
				q.enqueue((num * 10) + (last_dig - 1)) 
				q.enqueue((num * 10) + (last_dig + 1)) 

# Prints all jumping numbers smaller than or equal to 
# a positive number x 
def printJumping(x): 
	print (str(0), end =' ') 
	for i in range(1, 10): 
		bfs(x, i) 

# Driver Program ( Change value of x as desired ) 
x = 40
printJumping(x) 

# This code is contributed by Saket Modi

# %%
#gcd and lcm
def func(a,b): 
    if (b == 0): 
         return a 
    return func(b, a%b) 
n=int(input())
for i in range(n):
    m,n=map(int,input().split())
    g=func(m,n)
    print(m*n//g,g)

# %%
#adding_fraction
def addFraction(a,b,c,d):
    num=(a*d + c*b)
    deno=b*d
    gd=gcd(num,deno)
    print(num//gd,end="")
    print("/",end="")
    print(deno//gd)
#to_its_lowest_form    
def gcd(a,b):
    if b==0:
        return a
    return gcd(b,a%b)

# %%
#gcd_array
def gcd(a,b):
    if (b==0):
        return a
    return gcd(b,a%b)  
t=int(input())
for i in range(t):
    n=int(input())
    a=list(map(int,input().split()[:n]))
    ab=a[0]
    for i in range(n-1):
        if n==1:
            print(ab)
            break
        else:
            ab=gcd(ab,a[i+1])
    print(ab)

# %%
#fact
t=int(input())
for i in range(t):
    n=int(input())
    a=1
    while n>0:
        a=a*n
        n-=1
    print(a)    
 #3#
def fact(n):
    if n==0:
        return 1
    else:
        return n*(fact(n-1))
t=int(input())
for _ in range(t):
    n=int(input())
    print(fact(n))

# %%
#permu and comination
#npr=n!/(n-p)!
def fact(n):
    if n==0:
        return 1
    else:
        return n*(fact(n-1))
t=int(input())
for _ in range(t):
    n,p=list(map(int,input().split()))
    a=fact(n)
    b=fact(n-p)
    print(a//b)
#ncr=n!/r!*(n-r)!    
def fab(n):
    p=1
    for i in range(1,n+1):
        p=p*i
    return p


for i in range(int(input())):
    x,y=map(int,input().split())
    re=fab(x)//(fab(y)*fab(x-y))
    print(re%1000000007)

# %%
#prime and factor
t=int(input())
for i in range(t):
    n=int(input())
    a=[]
    for num in range(2,n+1):
        if num > 1:
            for i in range(2, num):
                if (num % i) == 0:
                    break
            else:
                #print(num)
                if n%num==0:
                    a.append(num)
    print(max(a))

# %%
#perfect_no.
t=int(input())
for i in range(t):
    n=int(input())
    a=[]
    d=n//2+1
    for i in range(1,d):
        if n%i==0:
            a.append(i)
    if sum(a)==n:
        print("1")
    else:
        print("0")
#####
from math import sqrt
t=int(input())
for i in range(t):
    n=int(input())
    l=[]
    l.append(1)
    print(sqrt(n))
    for i in range(2,int(sqrt(n))+1):
        if n%i==0:
            if n/i==i:
                l.append(i)
            else:
                l.append(n/i)
                l.append(i)
    print(int(n==int(sum(l))))

# %%
#a*3+b*3==n
import math
t=int(input())
for _ in range(t):
    n=int(input())
    count=0
    l=math.ceil(math.pow(n,1/3))
    for i in range(1,l+1):
        for j in range(0,l+1):
            #print(i,j)
            a=i**3
            b=j**3
            if (a+b)==n:
                count=count+1
    print(count)

# %%
#root of number
import math
t=int(input())
for _ in range(t):
    n,m=list(map(int,input().split()))
    l=math.pow(m,1/n)
    a=int(l)
    if l%a==0:
        print(a)
    else:
        print("-1")

# %%
#nth root of number
import math
for _ in range(int(input())):
    n, m = map(int, input().split())
    rt = m ** (1/n)
   # print(rt)
    fl = math.floor(rt)
    ce = math.ceil(rt)
    if m == fl**n:
        print(fl)
    elif m == ce**n:
        print(ce)
    else:
        print(-1)

# %%
#prime or not
t=int(input())
for _ in range(t):
    n=int(input())
    f=0
    if n%2==0:
        print('No')
    else:
        from math import sqrt
        for j in range(3,int(sqrt(n))+1):
            if n%j==0:
                f=1
                break
        if f==1:
            print('No')
        else:
            print('Yes')

# %%
#puzzles

# %%
#count_squares
from math import sqrt
t=int(input())
for _ in range(t):
    n=int(input())
    a=[]
    d=int(sqrt(n))
    while d>0:
        a.append(d**2)
        d-=1
    if n in a:
        a.remove(n)
    print(len(a))

# %%
#3_divisors
# learn square of prime no

# %%
#if coordinates  form a square
def distance(x1, y1, x2, y2):
    return sqrt((x1-x2)**2 + (y1-y2)**2)

def is_square(x1, y1, x2, y2, x3, y3, x4, y4):
    a = distance(x1, y1, x2, y2)
    b = distance(x1, y1, x3, y3)
    c = distance(x1, y1, x4, y4)
    if a==0 and b==0 and c==0:
        return False
    if a==b and c==sqrt(a**2+b**2):
        return True
    if b==c and a==sqrt(b**2+c**2):
        return True
    if c==a and b==sqrt(c**2+a**2):
        return True
    return False

t = int(input())
from math import sqrt

for _ in range(t):
    x1, y1, x2, y2, x3, y3, x4, y4 = map(int, input().split())
    _is = is_square(x1, y1, x2, y2, x3, y3, x4, y4)
    if _is:
        print("Yes")
    else:
        print("No")

# %%
#check_if _no_is_power
T=int(input())
while T>0:
    a,b = map(int,input().split())
    flag=0
    for i in range(int(b//2)+1):
        if(a**i==b):
            flag=1
            break
    print(flag)
    T=T-1

# %%
#arrays

# %%
#leaders_in_a_array
t=int(input())
for i in range(t):
    size=int(input())
    a=[]
    arr=list(map(int,input().split()[:size]))
    for i in range(0, size):
        for j in range(i+1, size): 
            if arr[i]<=arr[j]: 
                break
        if j == size-1:
            a.append(arr[i])
            
    li=' '.join(map(str,a))  
    print(li)

# %%
#subarrays
def sub_lists(list1):   
    sublist = []
    for i in range(len(list1) + 1): 
        for j in range(i + 1, len(list1) + 1):
            sub = list1[i:j] 
            sublist.append(sub) 
    return sublist 
li = [1, 2, 3] 
print(sub_lists(li))

# %%
#majority_element
t=int(input())
for i in range(t):
    n=int(input())
    arr=list(map(int,input().split()[:n]))
    x=set(arr)
    flag=0
    for i in x:
        if arr.count(i)>n/2:
            print(i)
            flag=1
    if flag==0:
        print('-1')
    #
from collections import Counter
t=int(input())
for i in range(t):
    n = int(input())
    arr = [int(i) for i in input().split()]
    ct = Counter(arr)
    found = -1
    for key, value in ct.items():
        if value > n//2:
            found = key
            break
    print(found)

# %%
#wave array
t=int(input())
for i in range(t):
    n = int(input())
    arr = [int(i) for i in input().split()]
    res=sorted(arr)
    for i in range(0,n-1,2): 
        res[i], res[i+1] = res[i+1],res[i] 
    str1=" ".join(map(str,res))
    print(str1)

# %%
#maximum_index
t=int(input())
for i in range(t):
    n=int(input())
    arr=list(map(int,input().split()))
    a=0
    b=n-1
    while arr[a]>arr[b]:
        temp_a=a
        temp_b=b
        while arr[temp_a]>arr[b]:
            temp_a+=1
        while arr[temp_b]<arr[a]:
            temp_b-=1
        if temp_a-a<b-temp_b:
            a+=1
        else:
            b-=1
    print(b-a)

# %% [markdown]
# # Strings

# %%
#palindrome
t=int(input())
for _ in range(t):
    n=int(input())
    a=input()
    if (a==a[::-1]):
        print('Yes')
    else:
        print('No')

# %%
#merge_two_strings
t=int(input())
for _ in range(t):
    a=input().split()
    ab=[]
    b=[]
    for i in a:
        bi=list(i)
        ab.append(bi)
    if len(a[0])>=len(a[1]):
        for i in range(len(a[1])):
            b.extend(ab[0][i]+ab[1][i])
        b.extend(ab[0][len(a[1]):])  
    if len(a[1])>len(a[0]):
        for i in range(len(a[0])):
            b.extend(ab[0][i]+ab[1][i])
        b.extend(ab[1][len(a[0]):])   
    str1="".join(map(str,b)) 
    print(str1)

# %%
#alphanumeric
t=int(input())
for _ in range(t):
    s1=input()
    l1=list(s1)
    str1=[]
    for i in l1:
        if i.isalnum()==True:
            str1.append(i)
    l = [item.lower() for item in str1]   
    if l==l[::-1]:
        print("YES")
    else:
        print("NO")

# %%
#urlify
t=int(input())
for _ in range(t):
    s1=input()
    n=int(input())
    x = s1.replace(" ", "%20")
    print(x)
